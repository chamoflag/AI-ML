# %% [markdown]
# <a href="https://colab.research.google.com/github/chamoflag/AI-ML/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('/content/mortgage_loan_dataset.csv')

# %% [markdown]
# To see the files available in your current working directory, you can use the `os` module to list its contents:

# %%
import os

# List all files and directories in the current directory
print(os.listdir('.'))
# Out:
# ['.config', 'mortgage_loan_dataset.csv', 'sample_data']

# %% [markdown]
# From the output, you can confirm the exact filename, which in this case is `mortgage_loan_dataset.csv`. Now, let's load it into a pandas DataFrame and display the first 5 rows to verify it loaded correctly.

# %%
df = pd.read_csv('mortgage_loan_dataset.csv')
display(df.head())
# Out:
#        loan_id  loan_amount  interest_rate  loan_term  borrower_income  \
# 0  LN-2026-001     450253.0           3.82         30          60956.0
# 1  LN-2026-002     548433.0           5.04         15          48352.0
# 2  LN-2026-003     350233.0           4.00         30          85699.0
# 3  LN-2026-004     551016.0           7.21         30         121944.0
# 4  LN-2026-005     542612.0           6.18         30              NaN
#
#    credit_score  property_value loan_purpose employment_type region  \
# 0         792.0        590000.0     Purchase   Self-Employed   East
# 1         739.0        734000.0     Purchase        Salaried   East
# 2         794.0        479000.0     Purchase        Salaried  South
# 3         740.0        662000.0    Refinance        Salaried   East
# 4         646.0        658000.0     Purchase        Salaried   West
#
#   loan_status
# 0  no_default
# 1     default
# 2  no_default
# 3     default
# 4     default

# %%
print(df.shape)
# Out:
# (50, 11)

# %%
df.head()
# Out:
#        loan_id  loan_amount  interest_rate  loan_term  borrower_income  \
# 0  LN-2026-001     450253.0           3.82         30          60956.0
# 1  LN-2026-002     548433.0           5.04         15          48352.0
# 2  LN-2026-003     350233.0           4.00         30          85699.0
# 3  LN-2026-004     551016.0           7.21         30         121944.0
# 4  LN-2026-005     542612.0           6.18         30              NaN
#
#    credit_score  property_value loan_purpose employment_type region  \
# 0         792.0        590000.0     Purchase   Self-Employed   East
# 1         739.0        734000.0     Purchase        Salaried   East
# 2         794.0        479000.0     Purchase        Salaried  South
# 3         740.0        662000.0    Refinance        Salaried   East
# 4         646.0        658000.0     Purchase        Salaried   West
#
#   loan_status
# 0  no_default
# 1     default
# 2  no_default
# 3     default
# 4     default

# %%
df.dtypes
# Out:
# loan_id             object
# loan_amount        float64
# interest_rate      float64
# loan_term            int64
# borrower_income    float64
# credit_score       float64
# property_value     float64
# loan_purpose        object
# employment_type     object
# region              object
# loan_status         object
# dtype: object

# %%
df.describe()
# Out:
#          loan_amount  interest_rate   loan_term  borrower_income  \
# count      50.000000      50.000000   50.000000        49.000000
# mean   423963.280000       7.128600   33.600000    102752.285714
# std    193649.469168      11.303123   47.488344     59048.618831
# min    -50000.000000       3.610000   15.000000         0.000000
# 25%    277236.500000       4.502500   30.000000     60606.000000
# 50%    448011.500000       5.575000   30.000000     85699.000000
# 75%    550370.250000       6.765000   30.000000    124146.000000
# max    753417.000000      85.000000  360.000000    214331.000000
#
#        credit_score  property_value
# count     49.000000    4.900000e+01
# mean     876.265306    5.297959e+05
# std     1333.107582    2.268552e+05
# min      350.000000    1.650000e+05
# 25%      629.000000    3.910000e+05
# 50%      706.000000    5.010000e+05
# 75%      749.000000    6.860000e+05
# max     9999.000000    1.038000e+06

# %%
df.isnull().sum()
# Out:
# loan_id            0
# loan_amount        0
# interest_rate      0
# loan_term          0
# borrower_income    1
# credit_score       1
# property_value     1
# loan_purpose       0
# employment_type    1
# region             0
# loan_status        0
# dtype: int64

# %%
df.isnull().sum()/len(df)*100
# Out:
# loan_id            0.0
# loan_amount        0.0
# interest_rate      0.0
# loan_term          0.0
# borrower_income    2.0
# credit_score       2.0
# property_value     2.0
# loan_purpose       0.0
# employment_type    2.0
# region             0.0
# loan_status        0.0
# dtype: float64

# %%
df.nunique()
# Out:
# loan_id            50
# loan_amount        50
# interest_rate      46
# loan_term           3
# borrower_income    49
# credit_score       46
# property_value     48
# loan_purpose        5
# employment_type     4
# region              4
# loan_status         2
# dtype: int64

# %%
df['loan_status'].value_counts()
# Out:
# loan_status
# no_default    28
# default       22
# Name: count, dtype: int64

# %%
df['loan_status'].value_counts(normalize=True)*100
# Out:
# loan_status
# no_default    56.0
# default       44.0
# Name: proportion, dtype: float64

# %%
df['borrower_income'].isnull().sum()
# Out:
# np.int64(1)

# %%
df[df['borrower_income'].isnull()]
# Out:
#        loan_id  loan_amount  interest_rate  loan_term  borrower_income  \
# 4  LN-2026-005     542612.0           6.18         30              NaN
#
#    credit_score  property_value loan_purpose employment_type region  \
# 4         646.0        658000.0     Purchase        Salaried   West
#
#   loan_status
# 4     default

# %%
df=df.dropn
